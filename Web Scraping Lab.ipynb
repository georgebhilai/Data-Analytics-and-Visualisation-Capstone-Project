# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Hands-on Lab : Web Scraping**

# %% [markdown]
# Estimated time needed: **30 to 45** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Extract information from a given web site
# -   Write the scraped data into a csv file.

# %% [markdown]
# ## Extract information from the given web site
#
# You will extract the data from the below web site: <br>

# %%
#this url contains the data you need to scrape
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/Programming_Languages.html"

# %% [markdown]
# The data you need to scrape is the **name of the programming language** and **average annual salary**.<br> It is a good idea to open the url in your web broswer and study the contents of the web page before you start to scrape.

# %% [markdown]
# Import the required libraries

# %%
# Your code here
# !pip install bs4
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests # this module helps us to download a web page
import pandas as pd
# Out:
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from beautifulsoup4->bs4) (2.3.1)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1270 sha256=fccc18e53fa1309c8cf923afb8ba75f0f690133b9036e4c2cd31bdd0e8c9a9e8
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1

# %% [markdown]
# Download the webpage at the url

# %%
#your code goes here
data = requests.get(url).text

# %% [markdown]
# Create a soup object

# %%
#your code goes here
soup = BeautifulSoup(data, 'html5lib')

# %% [markdown]
# Scrape the `Language name`, `Created By` `annual average salary`and `Learning Difficulty`.

# %%
#your code goes here
df = pd.DataFrame(columns=['Language Name', 'Average Salary', 'Learning Difficulty'])

for row in soup.find("tbody").find_all("tr"):
  col = row.find_all("td")
  language = col[1].text
  salary = col[3].text
  learning = col[4].text
df = df.append({'Language Name' : language, 'Average Salary' : salary, 'Learning Difficulty' : learning}, ignore_index=True)

df.drop(index=df.index[0], axis=0, inplace=True)
print(df)
# Out:
# Empty DataFrame
# Columns: [Language Name, Average Salary, Learning Difficulty]
# Index: []
# /tmp/wsuser/ipykernel_1195/3517648892.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Language Name' : language, 'Average Salary' : salary, 'Learning Difficulty' : learning}, ignore_index=True)

# %% [markdown]
# Create a _dataframe_ for scrapped data

# %%
#your code goes here



#drop first row
# Out:
# Empty DataFrame
# Columns: [Language Name, Average Salary, Learning Difficulty]
# Index: []
# /tmp/wsuser/ipykernel_1195/1423619901.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Language Name' : language, 'Average Salary' : salary, 'Learning Difficulty' : learning}, ignore_index=True)

# %% [markdown]
# Save the scrapped data into a file named _popular-languages.csv_

# %%
# your code goes here
df.to_csv('popular-languages.csv')

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
